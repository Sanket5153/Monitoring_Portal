# %% [markdown]
#  Import Data and Required Packages
# Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv("data/scheduler_data.csv")

# %% [markdown]
# Show Top 5 Records

# %%
df.head()
# Out:
#    id_array_job  id_array_task      id_user  kill_requid  nodes_alloc  \
# 0   41161693674     4595979483  66088413977  51671871839            0
# 1   41161693674     4595979483  66088413977  51671871839            1
# 2   41161693674     4595979483  16176946191  51671871839            1
# 3   41161693674     4595979483  16176946191  16176946191            1
# 4   41161693674     4595979483  16176946191  16176946191            1
#
#                nodelist  cpus_req  derived_ec  exit_code     gres_req  \
# 0                    []         1           0        256          NaN
# 1  ['r2684277-n303509']         1           0          0  gpu:volta:2
# 2  ['r5198790-n347934']         4       32512      32512  gpu:volta:1
# 3  ['r3541344-n655125']         4           0          0  gpu:volta:1
# 4  ['r3541344-n655125']         4           0          0  gpu:volta:1
#
#   gres_alloc  array_max_tasks  array_task_pending constraints  flags  \
# ...

# %% [markdown]
# Shape of the dataset

# %%
df.shape
# Out:
# (287173, 30)

# %% [markdown]
# ### Dataset information
# - gender : sex of students -> (Male/female)
# - race/ethnicity : ethnicity of students -> (Group A, B,C, D,E)
# - parental level of education : parents' final education ->(bachelor's degree,some college,master's degree,associate's degree,high school)
# lunch : having lunch before test (standard or free/reduced)
# test preparation course : complete or not complete before test
# math score
# reading score
# writing score

# %%
# Out:
# ['r2215649-n455332', 'r974863-n455332', 'r9648383-n455332', 'r44132-n455332', 'r4506251-n455332', 'r9480604-n455332', 'r8024255-n455332', 'r8473362-n455332', 'r492024-n455332', 'r9988778-n455332', 'r9515777-n455332', 'r7462820-n455332']

# %%
dataset['nodelist'] = [item for item in dataset['nodelist']]

# %%
print(dataset['nodelist'].iloc[60])
# Out:
# ['r2215649-n455332', 'r974863-n455332', 'r9648383-n455332', 'r44132-n455332', 'r4506251-n455332', 'r9480604-n455332', 'r8024255-n455332', 'r8473362-n455332', 'r492024-n455332', 'r9988778-n455332', 'r9515777-n455332', 'r7462820-n455332', 'r8141575-n455332', 'r8275852-n455332', 'r1039410-n953310', 'r2684277-n953310', 'r6727430-n953310', 'r7419443-n953310', 'r810901-n953310', 'r216287-n953310', 'r7269000-n953310', 'r4683026-n953310', 'r4144777-n953310', 'r7753495-n953310', 'r5179276-n953310', 'r4605940-n953310', 'r7317916-n953310', 'r9170217-n953310', 'r7141590-n953310', 'r3974592-n953310', 'r8972851-n953310', 'r414303-n953310', 'r2215649-n882168', 'r974863-n882168', 'r9648383-n882168', 'r44132-n882168', 'r4506251-n882168', 'r9480604-n882168', 'r8024255-n882168', 'r8473362-n882168', 'r492024-n882168', 'r9988778-n882168', 'r9515777-n882168', 'r7462820-n882168', 'r8141575-n882168', 'r8275852-n882168', 'r1039410-n877391', 'r2684277-n877391', 'r6727430-n877391', 'r7419443-n877391', 'r810901
# ...

# %%
dataset['nodelist'] = dataset['nodelist'].apply(lambda x: x.strip("[]") if isinstance(x, str) else x)

# %%
dataset['nodelist'].iloc[60]
# Out:
# "'r2215649-n455332', 'r974863-n455332', 'r9648383-n455332', 'r44132-n455332', 'r4506251-n455332', 'r9480604-n455332', 'r8024255-n455332', 'r8473362-n455332', 'r492024-n455332', 'r9988778-n455332', 'r9515777-n455332', 'r7462820-n455332', 'r8141575-n455332', 'r8275852-n455332', 'r1039410-n953310', 'r2684277-n953310', 'r6727430-n953310', 'r7419443-n953310', 'r810901-n953310', 'r216287-n953310', 'r7269000-n953310', 'r4683026-n953310', 'r4144777-n953310', 'r7753495-n953310', 'r5179276-n953310', 'r4605940-n953310', 'r7317916-n953310', 'r9170217-n953310', 'r7141590-n953310', 'r3974592-n953310', 'r8972851-n953310', 'r414303-n953310', 'r2215649-n882168', 'r974863-n882168', 'r9648383-n882168', 'r44132-n882168', 'r4506251-n882168', 'r9480604-n882168', 'r8024255-n882168', 'r8473362-n882168', 'r492024-n882168', 'r9988778-n882168', 'r9515777-n882168', 'r7462820-n882168', 'r8141575-n882168', 'r8275852-n882168', 'r1039410-n877391', 'r2684277-n877391', 'r6727430-n877391', 'r7419443-n877391', 'r810901
# ...
